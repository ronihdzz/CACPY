# %% [markdown]
# # Tarea_3
# ### Instrucciones: Lee bien lo que se te pide y responde

# %% [markdown]
# ## Ejericicio 1:
#
# A traves del siguiente clase crea una instancia cuyo nombre sea: *p1* y tenga como valores de atributos:
#
# * Nombre:   **juan**
# * Edad:     **19**
# * Estatura: **1.72**
# * Peso:     **59**

# %%
# No modificar el codigo de la clase Persona
class Persona():
    
  def __init__(self,nombre,edad,estatura,peso):
    '''
    Este el metodo constructor de las clase: Persona, el 
    cual se encargara de construir el objeto con las caracteristicas
    especificadas en los parametros.
            
    Parámetros:
        nombre (str): Nombre de la persona
        edad (int): Edad en años de la persona
        estatura (float): Sueldo de la persona
        peso (float): Sueldo de la persona

    Returns:
        Una instancia de la clase: 'Persona'
    '''
    
    self.nombre=nombre
    self.edad=edad
    self.estatura=estatura
    self.peso=peso

# %%
p1=None
### BEGIN SOLUTION
p1=Persona("juan",19,1.72,59)
### END SOLUTION

# %% [markdown]
# # Fin
# ![image.png](data:image/png;base64,...)

# %%
# Prueba 1
### BEGIN HIDDEN TESTS
assert p1.nombre == "juan"
### END HIDDEN TESTS

# %%
# Prueba 2
### BEGIN HIDDEN TESTS
assert p1.edad == 19
### END HIDDEN TESTS

# %%
# Prueba 3
### BEGIN HIDDEN TESTS
assert p1.estatura == 1.72
### END HIDDEN TESTS

# %%
# Prueba 4
### BEGIN HIDDEN TESTS
assert p1.peso == 59
### END HIDDEN TESTS
