# %% [markdown]
# # Tarea_4
# ### Instrucciones: Lee bien lo que se te pide y responde

# %% [markdown]
# ######  Ejericicio 1-. (50 puntos)
#
#
# A continuación se presenta la clase **Triangulo** con sus respectivos metodos de instancia, y su respectiva programación en python.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Lo que tu tienes que hacer es crear una instancia de la clase **Triangulo** y almacenarla en una variable cuyo nombre sea:  **t1** con los siguientes valores en los atributos:
#
# * altura= **10**
# * base= **5**
#
# **Por favor no editar el codigo de la clase: Triangulo**

# %%
#####################################################
# NO MODIFICAR EL CODIGO DE LA CLASE TRIANGULO
#####################################################
class Triangulo():
    def __init__(self, altura,base):
        '''
        Este el metodo constructor de las clase: Triangulo, el 
        cual se encargara de construir el objeto con las caracteristicas
        especificadas en los parametros.
        
        Parámetros:
            altura (float): representa la medida de la altura de un triangulo
            base (float): representa la medida de la base de un triangulo

        Returns:
            Una instancia de la clase: 'Triangulo'
        
        '''
        self.altura=altura
        self.base=base
        

# Apartir de aqui puedes comenzar a codificar




### BEGIN SOLUTION
t1=Triangulo(10,5)
### END SOLUTION

# %% [markdown]
# ######  Ejericicio 2-. (50 puntos)
#
# A continuación se presenta la clase: **Libro** con sus respectivos metodos de instancia, y su respectiva programación en python.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Lo que tu tienes que hacer es crear una instancia de la clase 'Libro' y almacenarla en una variable cuyo nombre sea:  **miLibro** con los siguientes valores en los atributos:
#
# * titulo=**caperucita**
# * autor=**roni**
# * paginas=**10**
#
# **Por favor no editar el codigo de la clase: Libro**

# %%
#####################################################
# NO MODIFICAR EL CODIGO DE LA CLASE LIBRO
#####################################################
class Libro():
    def __init__(self,titulo,autor,paginas):
        '''
        Este el metodo constructor de las clase: Libro, el 
        cual se encargara de construir el objeto con las caracteristicas
        especificadas en los parametros.
        
        Parámetros:
            titulo (str): representa el nombre del libro
            autor (str): representa el nombre del autor del libro
            paginas (int): representa el numero de paginas del libro

        Returns:
            Una instancia de la clase: 'Libro'
        '''
        
        self.titulo=titulo
        self.autor=autor
        self.paginas=paginas
        
        
# Apartir de aqui puedes comenzar a codificar




### BEGIN SOLUTION
miLibro=Libro('caperucita','roni',10)
### END SOLUTION

# %% [markdown]
# ######  Ejericicio 3-. (50 puntos)
#
# A continuación se presenta la clase: **Persona** con sus respectivos metodos de instancia, y su respectiva programación en python.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Lo que tu tienes que hacer es crear una instancia de la clase 'Persona' y almacenarla en una variable cuyo nombre sea:  **yo** con los siguientes valores en los atributos:
#
# * nombre=**pedro**
# * edad=**22**
# * estatura=**1.73**
# * peso=**62**
#
# **Por favor no editar el codigo de la clase: Persona**

# %%
#####################################################
# NO MODIFICAR EL CODIGO DE LA CLASE LIBRO
#####################################################
class Persona():
    def __init__(self,nombre,edad,estatura,peso):
        '''
        Este el metodo constructor de las clase: Persona, el 
        cual se encargara de construir el objeto con las caracteristicas
        especificadas en los parametros.
            
        Parámetros:
            nombre (str): Nombre de la persona
            edad (int): Edad en años de la persona
            estatura (float): Sueldo de la persona
            peso (float): Sueldo de la persona

        Returns:
            Una instancia de la clase: 'Persona'
        '''
        
        self.nombre=nombre
        self.edad=edad
        self.estatura=estatura
        self.peso=peso
        

# Apartir de aqui puedes comenzar a codificar 

        
        
### BEGIN SOLUTION
yo=Persona('pedro',22,1.73,62)
### END SOLUTION

# %% [markdown]
# # Fin
# ![image.png](data:image/png;base64,...)

# %%
# Prueba 1: instancia_Triangulo
### BEGIN HIDDEN TESTS
assert t1.base==5
assert t1.altura==10
### END HIDDEN TESTS

# %%
# Prueba 2: instancia_Libro
### BEGIN HIDDEN TESTS
assert miLibro.titulo=='caperucita'
assert miLibro.autor=='roni'
assert miLibro.paginas==10
### END HIDDEN TESTS

# %%
# Prueba 3: instancia_Persona 
### BEGIN HIDDEN TESTS
assert yo.nombre=='pedro'
assert yo.edad==22
assert yo.estatura==1.73
assert yo.peso==62
### END HIDDEN TESTS
